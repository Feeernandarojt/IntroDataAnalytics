# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Transacciones_Fraude.csv', sep=';', encoding='latin-1')
df
# Out:
# <ipython-input-4-ddb761f1850a>:1: DtypeWarning: Columns (7,8,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Transacciones_Fraude.csv', sep=';', encoding='latin-1')
#              UTRNNO            HPAN   FECHA_TRX  HORA_TRX COUNTRY_CODE  \
# 0      145736384287  93549332211627  2024-07-01   8:12:00           CO
# 1      145736384281  84409332211536  2024-07-01  18:47:00           CO
# 2      145736384252  84400332211005  2024-07-01   2:05:00           CO
# 3      145736384246  93526332211167  2024-07-01  13:51:00           CO
# 4      145736384197  93530332211347  2024-07-01  15:47:00           CO
# ...             ...             ...         ...       ...          ...
# 19815  145736366983  93530332211608  2024-07-30   2:51:00           CO
# 19816  145736366939  84491332211221  2024-07-30  22:02:00           CO
# 19817  145736366929  84416332211814  2024-07-30  19:29:00           CO
# ...

# %%
df.dtypes
# Out:
# UTRNNO                int64
# HPAN                  int64
# FECHA_TRX            object
# HORA_TRX             object
# COUNTRY_CODE         object
#                      ...
# AMOUNT_COL          float64
# BANCO_ADQUIRENTE     object
# AMBIENTE             object
# BANCO_EMISOR         object
# IS_FRAUD            float64
# Length: 106, dtype: object

# %%
# 1. Ver si el DF tiene filas con nulos
# En caso de tenr nulos eminarlos

# 2. Separar en columnnas numericas y categoricas
# 3. HAcer el analis de las columnas del df

# Dame un modelo de clasificacion binaria (1, 0) a partir de un df de fraudes con columnas numericas y strings, en donde utilices, correlacion de variables, train_test_split,  plots mas importantes, un imputador, un scalador, un modelo de regresion, confusion_matrix, classification_report, accuracy_score
